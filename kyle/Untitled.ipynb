# %%
from keras.models import Sequential

model = Sequential()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-cf6e072412f4> in <module>()
# ----> 1 from keras.models import Sequential
#       2
#       3 model = Sequential()
#
# ImportError: No module named keras.models
